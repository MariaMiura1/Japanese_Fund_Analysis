# %%
import glob
import os
import pdfplumber
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

print("Librerías cargadas correctamente")
# Out:
# Librerías cargadas correctamente

# %%
import os
os.getcwd()
# Out:
# '/workspaces/Japanese_Fund_Analysis/notebooks/notebooks'

# %%
import pdfplumber

target_pdf = "../../data/raw_pdf/SRI_report202509.pdf"

full_text = ""

with pdfplumber.open(target_pdf) as pdf:
    for page in pdf.pages:
        full_text += page.extract_text() or ""

print("Texto cargado correctamente")
print("Longitud:", len(full_text))
# Out:
# Texto cargado correctamente
# Longitud: 8378

# %%
'/workspaces/Japanese_Fund_Analysis/notebooks/notebooks'
# Out:
# '/workspaces/Japanese_Fund_Analysis/notebooks/notebooks'

# %%
import pdfplumber

target_pdf = "../../data/raw_pdf/SRI_report202509.pdf"

full_text = ""
with pdfplumber.open(target_pdf) as pdf:
    for page in pdf.pages:
        full_text += page.extract_text() or ""

print("OK - texto cargado")
print("chars:", len(full_text))
print(full_text[:800])
# Out:
# OK - texto cargado
# chars: 8378
# Japan Value Equity SRI
# September 2025
# Strategy
# SRI Strategy invests in Japanese equities which meet the criteria of ESG (Environmental, Social, Governance)
# managementandinvestmentvalue,andaimstoachieveabovebenchmark returninthemid-tolong-term.Ourequity
# investment takes a bottom-up approach in which the Japanese equity research team analyzes intrinsic value of
# individual stocks and compares it with market price in order to identify undervalued stocks. ESG research is
# conductedbySompoRiskManagement,whichisaleadingcompanyindomesticESGresearch.
# Market Review
# Japanesemarket prices rose on heightened expectations for Fed rate cuts and expansionaryfiscal policyfollowing the
# change in Prime Minister in Japan. Growth in the nonferrous and electric appliances, driven by increased expectations
# for AI
